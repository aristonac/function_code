# %%
import numpy as np
import pandas as pd
import os
import math
import statistics
# Out:
# Das Ausführen von Zellen mit „Python 3.9.12 64-bit“ erfordert das ipykernel-Paket.
#
# Führen Sie den folgenden Befehl aus, um „ipykernel“ in der Python-Umgebung zu installieren.
#
# Befehl: „c:/Users/ML/AppData/Local/Programs/Python/Python39/python.exe -m pip install ipykernel -U --user --force-reinstall“

# %%
def get_statistic(name_of_path):
    slices_path = name_of_path
    data_output = os.listdir(slices_path)
    for i in data_output:
        print(i)
        data_ = os.path.join(slices_path,i)
        data = np.loadtxt(data_,dtype=float)
#         print(data)
        data_x = data[:,1].tolist()
        data_y = data[:,2].tolist()
        df = pd.DataFrame(list(zip(data_x,data_y)),
               columns =['x', 'y'])
        
        #make empty list
        data_result = []
        for i in df['x']:
            for j in df['y']:
                #save the value in input_x and input_y
                input_x = i*4096
                input_y = j*3000
        #         input_x = i
        #         input_y = j

                for n in range(len(df['x'])):


                    #print(df['x'][n],df['y'][n])

                    if i != df['x'][n] and j!=df['y'][n]:

                        #data_result.append(math.sqrt((i-df['x'][n])*(i-df['x'][n])+(j-df['y'][k])*(j-df['y'][k])))
                        data_result.append(math.sqrt((i-df['x'][n]*4096)*(i-df['x'][n]*4096)+(j-df['y'][n]*3000)*(j-df['y'][n]*3000)))
                    else:
                        None
                        
        data_result.sort()
        print('The median is ',statistics.median(data_result[:len(df['x'])*3]))
        print('The mean is ',statistics.mean(data_result[:len(df['x'])*3]))

# %%
get_statistic(r'C:/Users/ML/venv_yolov5/yolov5/test_label/')
# Out:
# 20210813-14-49-14-059771_B49II_matrix_001.txt
# The median is  720.6690398987423
# The mean is  720.6728823052628
# 20210813-14-49-14-437646_B49II_matrix_001.txt
# The median is  584.9535219854739
# The mean is  584.9452331603975
# 20210813-14-49-14-621782_B49II_matrix_001.txt
# The median is  667.4233995841985
# The mean is  667.4343246025802
# 20210813-14-49-14-980723_B49II_matrix_001.txt
# The median is  286.63854523938596
# The mean is  286.6294634294137
# 20210813-14-49-15-199837_B49II_matrix_001.txt
# The median is  554.9013906908926
# The mean is  554.9107233293968
# 20210813-14-49-15-520710_B49II_matrix_001.txt
# The median is  258.29637614200567
# The mean is  258.29346935853187
# 20210813-14-49-15-854764_B49II_matrix_001.txt
# The median is  561.6156236208626
# The mean is  561.6329028033203
# 20210813-14-49-16-022691_B49II_matrix_001.txt
# The median is  760.2534631106505
# The mean is  760.2425607075833
# 20210813-14-49-16-348475_B49II_matrix_001.txt
# The median is  561.9450195565191
# The mean is  561.9430656262739
# 20210813-14-49-16-670778_B49II_matrix_001.txt
# The median is  241.6509549046857
# The mean is  241.62387289916057
# 20210813-14-49-17-161808_B49II_matrix_001.txt
# The median is  666.5031711145048
# The mean is  666.4918500454398
# 20210813-14-49-17-483931_B49II_matrix_001.txt
# The median is  583.479299617659
# The mean is  583.479357143858
# 20210813-14-49-17-797637_B49II_matrix_001.txt
# The median is  754.5309203908758
# The mean is  754.5216623003075
# 20210813-14-49-18-112381_B49II_matrix_001.txt
# The median is  496.9825172533816
# The mean is  496.9728463465708
# 20210813-14-49-18-267792_B49II_matrix_001.txt
# The median is  569.7950973834836
# The mean is  569.8028766391474
# 20210813-14-49-18-537594_B49II_matrix_001.txt
# The median is  804.4768025327953
# The mean is  804.4632226685279
# 20210813-14-49-18-837711_B49II_matrix_001.txt
# The median is  527.4089460064022
# The mean is  527.4018159952376
# 20210813-14-49-19-157855_B49II_matrix_001.txt
# The median is  212.92000170043846
# The mean is  212.92069712788233
# 20210813-14-49-19-388644_B49II_matrix_001.txt
# The median is  497.5220392660081
# The mean is  497.5373127825809
# 20210813-14-49-19-661741_B49II_matrix_001.txt
# The median is  632.8297608882372
# The mean is  632.8314150494832
# 20210813-14-49-20-000690_B49II_matrix_001.txt
# The median is  469.05654916285005
# The mean is  469.0546798199178
# 20210813-14-49-20-231687_B49II_matrix_001.txt
# The median is  559.8804539299756
# The mean is  559.8467241134124
# 20210813-14-49-20-506692_B49II_matrix_001.txt
# The median is  323.33904522593355
# The mean is  323.3340342808691
# 20210813-14-49-20-830420_B49II_matrix_001.txt
# The median is  653.5329003164459
# The mean is  653.5242147723465
# 20210813-14-49-21-070789_B49II_matrix_001.txt
# The median is  299.78537196486445
# The mean is  299.78339361984456
# 20210813-14-49-21-352710_B49II_matrix_001.txt
# The median is  554.8793370862891
# The mean is  554.8640352651428
# 20210813-14-49-21-676714_B49II_matrix_001.txt
# The median is  860.8364846381478
# The mean is  860.8215650342291
# 20210813-14-49-22-022639_B49II_matrix_001.txt
# The median is  398.9511133671674
# The mean is  398.9314883352494
# 20210813-14-49-22-191183_B49II_matrix_001.txt
# The median is  653.8255548785113
# The mean is  653.811730792047
# 20210813-14-49-22-479666_B49II_matrix_001.txt
# The median is  527.0119428471339
# The mean is  527.0140187584669
# 20210813-14-49-22-824188_B49II_matrix_001.txt
# The median is  707.6274060256854
# The mean is  707.6248064327169
# 20210813-14-49-23-033677_B49II_matrix_001.txt
# The median is  404.4399897065007
# The mean is  404.4320618872047
# 20210813-14-49-23-313667_B49II_matrix_001.txt
# The median is  207.0362229653097
# The mean is  207.0326864686127
# 20210813-14-49-23-944735_B49II_matrix_001.txt
# The median is  540.8960307000076
# The mean is  540.9075886725343
# 20210813-14-49-24-154763_B49II_matrix_001.txt
# The median is  261.43160934926027
# The mean is  261.4283183128775
